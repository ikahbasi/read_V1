# %%
# import function
from v1 import read_v1

# define file path
path = './some_v1.V1'
# Out:
# enter command "help2me()" if you need it

# %%
st = read_v1(path, method='obspystream')
st.plot()
print(st)
# Out:
# 3 Trace(s) in Stream:
# .TABAS..L1 | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:48.980000Z | 200.0 Hz, 9797 samples
# .TABAS..L2 | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:48.980000Z | 200.0 Hz, 9797 samples
# .TABAS..L3 | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:48.980000Z | 200.0 Hz, 9797 samples

# %%
import matplotlib.pyplot as plt

part1, part2, part3 = read_v1(path, method='ascii')

name, time, data = part1

plt.plot(time, data, label=name)
plt.legend()
plt.show()

# %%
(part1, part2, part3), st = read_v1(path, method='both')
print(st)
# Out:
# 3 Trace(s) in Stream:
# .TABAS..L1 | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:48.980000Z | 200.0 Hz, 9797 samples
# .TABAS..L2 | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:48.980000Z | 200.0 Hz, 9797 samples
# .TABAS..L3 | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:00:48.980000Z | 200.0 Hz, 9797 samples
